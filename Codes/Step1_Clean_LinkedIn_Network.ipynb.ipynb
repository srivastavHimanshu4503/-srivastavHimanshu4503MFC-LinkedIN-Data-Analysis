# %%
import os
import pandas as pd

# Set your paths
RAW_DIR = "Assignment 2/Data Connections"
CLEANED_DIR = "Assignment 2/Cleaned Connections"

# Create cleaned folder if it doesn't exist
os.makedirs(CLEANED_DIR, exist_ok=True)

# %%
def extract_student_name_from_filename(filename):
    try:
        name_part = filename.split(' - ')[-1].replace('.csv', '')
        name_words = name_part.strip().split()
        cleaned_name = '_'.join([word.title() for word in name_words])
        return cleaned_name
    except Exception as e:
        print(f"Error in filename parsing: {filename}, {e}")
        return None

# %%
def get_cleaned_full_name(first, last):
    if pd.isna(first) and pd.isna(last):
        return None  # Skip if both are missing

    first = str(first).strip() if pd.notna(first) else ''
    last = str(last).strip() if pd.notna(last) else ''
    
    full_name = (first + ' ' + last).strip()
    name_words = full_name.split()
    cleaned_name = '_'.join([word.title() for word in name_words])
    
    return cleaned_name if cleaned_name else None

# %%
for file in os.listdir(RAW_DIR):
    if not file.endswith(".csv"):
        continue
    
    file_path = os.path.join(RAW_DIR, file)

    # Try reading with UTF-8, fallback to ISO-8859-1
    try:
        df = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        try:
            df = pd.read_csv(file_path, encoding='ISO-8859-1')
            print(f"[Warning] Used fallback encoding for {file}")
        except Exception as e:
            print(f"[Error] Could not read {file} with fallback encoding: {e}")
            continue
    except Exception as e:
        print(f"[Error] Could not read {file}: {e}")
        continue

    cleaned_rows = []

    for _, row in df.iterrows():
        cleaned_name = get_cleaned_full_name(row.get("First Name"), row.get("Last Name"))
        if cleaned_name:
            company = row.get("Company", "")
            cleaned_rows.append({
                "Full Name": cleaned_name,
                "Company": company
            })

    if cleaned_rows:
        cleaned_df = pd.DataFrame(cleaned_rows)
        output_path = os.path.join(CLEANED_DIR, file)
        cleaned_df.to_csv(output_path, index=False)
        print(f"✅ Saved cleaned file: {output_path}")
    else:
        print(f"⚠️ No valid rows in file: {file}")
# Out:
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Aaditya_Raj - Aaditya Raj.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Abhishek_Singh - Abhishek Singh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Aditya_Singh - Aditya NO-LASTNAME.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Afzal_Raza - Afzl Raza.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ajay Jatav Connections-1 - Ajay Jatav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ajit_Yadav - Ajit Yadav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Akanksha_Kushwaha - Akanksha.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Alok_raj - Alok Raj.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Aman_ Adarsh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Aman_Singh - Aman Singh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\amit_kumar - Amit Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Anamika_Kumari - Anamika Kumari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Anand_Pandey - Anand Pandey.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Anoop_Kumar - ANOOP KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Anshu_Kumar - Anshu Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Anuradha_Tiwari - Anuradha Tiwari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Anushri_Mishra - Anushri Mishra.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Aradhya_Patel - Aradhya Patel.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Arjun Kadam - Arjun Kadam.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Arpita_Tripathi - Arpita Tripathi.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Arun_Singh - ARUN KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\aryan_saini - Aryan Saini.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ashwin_Yadav - Ashwin Yadav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ayush_Kumar - Ayush Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ayush_yadav - AYUSH YADAV.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Bhagwati_Chouhan - Bhagwati NO-LASTNAME.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Bhaskar_mahato - Bhaskar Mahato.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\ByagariPraveen_Kumar - Byagari Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Challa_Trivedh_Kumar - CHALLA TRIVEDH KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\CHANDAN_GIRI - Chandan Giri.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Chiranjeet_Biswas - Chiranjeet Biswas.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Cleaned_Connections - Bhagwan Singh Rawat.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Connection - VISHAL KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\connection1-1 - Aman Adarsh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Connections - Aman Verma.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Connections - Anand Singh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Connections - Harshit Chaturvedi.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\connections - N.Arun Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Connections - Ompal Yadav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Connections - RAVI RAJPUT.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\debangsu_misra.csv - Debangsu Misra.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Dilip_Suthar - DILIP SUTHAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Disha_Sahu - Disha Sahu.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Divyanshi_Rathour - Divyanshi Rathour.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Divyanshi_Sahu.csv - Divyanshi Sahu.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ekta Kumari - Ekta Kumari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\gaurav_khainwar.csv - Gaurav Khainwar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Gaurav_Rathore - Gaurav Rathore.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Gaurav_Tiwari - GAURAV TIWARI.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Harisingh_Rajpoot - Harisingh Rajpoot.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\HimanshuKanwarChundawat - Himanshu Chundawat.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Himanshu_kumar - Himanshu Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Himanshu_Srivastav - Himanshu Srivastav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Hiranya_Patil - Hiranya Patil.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ishant_Bhoyar - ISHANT BHOYAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\JAMAL_AKHTAR - JAMAL AKHTAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Janu_Chaudhary - Janu Chaudhary.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\KARANPAL_SINGH_RANAWAT - KARANPAL SINGH RANAWAT.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\khushi_narwariya - Khushi Narwariya.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Kuldeep_Saraswat - Kuldeep saraswat.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Lakhan_Rathore - Lakhan Rathore.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\linkedin list - Nidhi Kumari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\linkedin_Connections - SNEHA SHAW.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Linked_in_connection - Samina Sultana.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Maneesh_Sakhwar - Maneesh Sakhwar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Manish_Tiwari - MANISH KUMAR TIWARI.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Manoj K. Connections - MANOJ KHARKAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Manoj_Dewda - Manoj Dewda.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Mausam_kumari - Mausam kumari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Mayank_Raj - Mayank Raj.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Mehtab_Alam - MEHTAB ALAM.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Mohd_Monis - Monis.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Mohit_Sharma - Mohit Sharma.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Monu_Rajpoot - Monu Rajpoot.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Naman_Damami - Naman Damami.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Neeraj_Parmar - NEERAJ PARMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Nikhil_Chaurasiya - Nikhil Chaurasiya.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Nirmal LinkdIn Connections - NIRMAL MEWADA.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Pawan_Kushwah - Pawan Kushwah.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Pinky_Rana - Pinky Rana.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Prabhat_Patidar - prabhat patidar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Prachi_Dhakad - PRACHI DHAKAD.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Pragati_Chauhan - Pragati Chauhan.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Pranjal_Dubey - Pranjal Dubey.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Prem kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Prerana_Rajnag - PRERANA RAJNAG.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Priyadarshi_Kumar - Priyadarshi Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Priya_saini - Priya Saini.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Pushpraj_Singh.csv - Pushpraj Singh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Rahul_Kumar - Rahul Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Rahul_Kumar_Verma - Rahul Verma.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Rajiv_Kumar - RAJIV KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ramraj_Nagar - Ramraj Nagar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Rani_Kumari - Rani Kumari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ranjeet_Kumar_Yadav - Ranjeet Yadav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ravi_Mourya - Ravi Mourya.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ritik_Singh - ritik singh.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Rohit_kumar - ROHIT KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Rohit_Malviya - Rohit Malviya.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sajan_Kumar - SAJAN KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Samina_Sultana.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sandeep_kumar - Sandeep Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sandhya_Kaushal - Sandhya Kaushal.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sandhya_Parmar - Sandhya Parmar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sarthaksuman_Mishra - Sarthak Mishra.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Satish_Mahto - Satish Mahto.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sauhard_kumar - Sauhard kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Saurabh_Bisht - Saurabh Bisht.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shahid_Ansari - Shahid Ansari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shilpi_Shaw - Shilpi Shaw.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shivam_Shukla.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shivang_Dubey - Shivang Dubey.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shlok_Gupta - Shlok Gupta.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shubham Kumar - Shubham Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Shubham_Kang - Shubham Kang.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sneha_Shaw.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Sunny_Kumar - Sunny Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Suyash_Yadav - Suyash Yadav.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Swati_Kumari - Swati kumari.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Ujjval_Baijal - Ujjval Baijal.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Uppara Sai_Maithreyi - UPPARA MAITHREYI.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Vinay_Gupta - VINAY GUPTA.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Vinay_Kumar - VINAY KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Vishal_Bhardwaj - VISHAL BHARDWAJ.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Vivek_kumar - VIVEK KUMAR.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Vivek_Singh - Vivek Kumar.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\YuvrajSingh_Bhati - Yuvraj Bhati.csv
# ✅ Saved cleaned file: Assignment 2/Cleaned Connections\Yuvraj_Chirag - Yuvraj Chirag.csv
